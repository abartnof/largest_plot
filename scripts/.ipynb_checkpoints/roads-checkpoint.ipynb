# %% [markdown]
# https://safety.fhwa.dot.gov/geometric/pubs/mitigationstrategies/chapter3/3_lanewidth.cfm

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point, box, LineString
from shapely import intersection

target_epsg = 6350  # https://epsg.org/crs_6350/NAD83-2011-Conus-Albers.html?sessionkey=nb47agmo4r

# %%
fn = '/Volumes/Extreme SSD/largest_plots/raw_data/roads/tl_2023_01001_roads.zip'

# %%
File = gpd.read_file(fn)

# %%
File
# Out:
#             LINEARID                        FULLNAME RTTYP  MTFCC  \
# 0      1103672784948                    McGee Rd Exn     M  S1400
# 1      1103677525952                    Buena Vis Lp     M  S1400
# 2       110585093547  Alt Rte Route County Road 40 W     O  S1400
# 3       110585093535        Alt Rte Route Co Rd 40 W     O  S1400
# 4       110585093545           Alt Rte Route Cord 59     O  S1400
# ...              ...                             ...   ...    ...
# 2568    110585080900                         Burt Ln     M  S1400
# 2569    110585083257                      Crows Pass     M  S1400
# 2570  11016955028584                            None  None  S1400
# 2571   1103717516384                      Rollins Rd     M  S1400
# 2572   1103717516370                       Co Rd 131     C  S1400
#
#                                                geometry
# 0     LINESTRING (-86.68571 32.60424, -86.68572 32.6...
# 1     LINESTRING (-86.44949 32.42550, -86.44939 32.4...
# ...
