# %% [markdown]
# # Munge national shapefile
#
# thinking through the array steps:
# https://stackoverflow.com/questions/31820107/is-there-a-numpy-function-that-allows-you-to-specify-start-step-and-number
#
# keep doing intersects and then for each shape left over, find the one with the point therein?
# https://gis.stackexchange.com/questions/455159/cut-a-polygon-based-on-lines-from-another-layer-in-geopandas
#
# conic albers, a projection for the lower 48 that maintains area equality
# https://epsg.org/crs_5072/NAD83-NSRS2007-Conus-Albers.html?sessionkey=nb47agmo4r
#
# shapely subtraction
# https://stackoverflow.com/questions/61930060/how-to-use-shapely-for-subtracting-two-polygons

# %%
import pandas as pd
import geopandas as gpd
# from haversine import inverse_haversine, Unit, Direction, haversine
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point, box, LineString
# from tqdm.notebook import tqdm
# from itertools import compress
# from skimage.measure import grid_points_in_poly, points_in_poly
# from ray import train, tune

# Conic, equal-area map projection; meters in lieu of geodetic coords
target_epsg = 6350  # https://epsg.org/crs_6350/NAD83-2011-Conus-Albers.html?sessionkey=nb47agmo4r

# %%
fn_coords = '/Volumes/Extreme SSD/largest_plots/clean_data/colo_sites(202409301939).csv'
CoordsRaw = pd.read_csv(fn_coords)

# %% [markdown]
# # Set up area of interests

# %%
geometry = [Point(xy) for xy in zip(CoordsRaw.longitude, CoordsRaw.latitude)]
Coords = gpd.GeoDataFrame(CoordsRaw, geometry=geometry)
Coords.set_crs(epsg=4326, inplace=True)  # Default used in GPS https://epsg.io/4326#google_vignette
Coords.to_crs(epsg=target_epsg, inplace=True)

# Create 'buffers', aka, areas of interest
aoi_list = Coords.buffer(1e3*50, cap_style='square')  # Necessary to turn a pt into a square
Aoi = gpd.GeoDataFrame({'aoi':aoi_list})
Aoi.set_geometry('aoi', inplace=True)
Aoi.set_crs(epsg=target_epsg, inplace=True)
Aoi.head()
# Out:
#                                                  aoi
# 0  POLYGON ((1064783.733 1251341.503, 1064783.733...
# 1  POLYGON ((1253970.757 1246193.050, 1253970.757...
# 2  POLYGON ((1280030.297 1420238.314, 1280030.297...
# 3  POLYGON ((1652992.164 1570284.428, 1652992.164...
# 4  POLYGON ((1517647.954 1484669.498, 1517647.954...

# %%
# Sanity check-- are these buffer areas correct?
all(
    Aoi.area.round() == 
    (1e3*50*2)**2
)
# Out:
# True

# %% [markdown]
# # National boundary

# %%
fn_nation_shape = '/Volumes/Extreme SSD/largest_plots/raw_data/cb_2021_us_all_5m/cb_2021_us_nation_5m.zip'
NationShape = gpd.read_file(fn_nation_shape).to_crs(epsg=target_epsg)
NationShape.head()
# Out:
#     AFFGEOID GEOID           NAME  \
# 0  0100000US    US  United States
#
#                                             geometry
# 0  MULTIPOLYGON (((-5215608.250 5698763.159, -521...

# %%
NationShapeOverlay = gpd.overlay(Aoi, NationShape, how='intersection')

# %%
is_max_area = NationShapeOverlay.area.round() == NationShapeOverlay.area.round().max()

maps = {True: "black", False: "red"}
NationShapeOverlay['color'] = [maps[value] for value in is_max_area.values]


# fig, ax = plt.subplots(figsize=(10, 10))
# ax.set_xlim(-.3e7, .3e7)
# ax.set_ylim(0, .35e7)
# NationShape.plot(ax=ax, color='blue')
# NationShapeOverlay.plot(ax=ax, color = NationShapeOverlay['color'])
# plt.show()

del NationShape

# %% [markdown]
# # Experiment on lines

# %%
s = gpd.GeoSeries(LineString(
    [(0, 0), (0, 10)]
    )
)
s.buffer(distance=1, cap_style='flat').area
# Out:
# 0    20.0
# dtype: float64

# %% [markdown]
# ## Rails

# %%
fn_rails = '/Volumes/Extreme SSD/largest_plots/raw_data/tl_2023_us_rails.zip'
Rails = gpd.read_file(fn_rails).to_crs(epsg=target_epsg)

# %%
i = 0
RailSubset = gpd.sjoin(Rails, Aoi.loc[[i]], how='inner', predicate='intersects')

# %%
RailPolygons = RailSubset.buffer(distance=1000, cap_style='round', single_sided=False)  # TODO: delete this
# RailPolygons = RailSubset.buffer(distance=1, cap_style='round')  # TODO: use this # round prevents breaks in the lines

# %%
rail_polygon_flat = RailPolygons.unary_union

# %%
Aoi.aoi[i].intersection(rail_polygon_flat)
# Out:
# <POLYGON ((1.06e+06 1.25e+06, 1.06e+06 1.25e+06, 1.06e+06 1.25e+06, 1.06e+06...>

# %%
area_diff = Aoi.aoi[i].difference(RailPolygons.unary_union).area
print(Aoi.aoi[i].area - rail_polygon_flat.area)
print(area_diff)
# Out:
# 8688821724.313698
# 8864094555.972527

# %%
fig, ax = plt.subplots(figsize=(15, 15))
Aoi.loc[[i]].plot(ax=ax)
# RailPolygons.plot(ax=ax, color = 'pink')
RailPolygonsFlat.plot(ax=ax, alpha=1, color="red")
# Out:
# <Axes: >

# %%
gpd.overlay(Aoi[[i]], RailPolygonsFlat, how='intersection')
# Out:
#                                                  aoi
# 0  POLYGON ((1064783.733 1251341.503, 1064783.733...

# %%
BufferedRails.area
# Out:
# /var/folders/zh/p6wj0vfs3qq684w4b1m0_tvr0000gn/T/ipykernel_7503/3291341107.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   BufferedRails.area
# 22951     1.123716e-06
# 22952     1.346950e-06
# 22953     1.123716e-06
# 22954     3.196775e-06
# 22955     1.346950e-06
#               ...
# 117302    2.209258e-06
# 117303    8.983368e-07
# 117313    5.085826e-07
# 117314    9.060636e-07
# 117564    6.893597e-07
# Length: 192, dtype: float64

# %%
buffer_distance = np.mean((step_lat, step_long))

JoinRails = Rails.sjoin(BoundingBox, how="inner", predicate='intersects')
JoinRails.to_crs(crs=3857).crs
# BufferedRails = JoinRails.buffer(distance=buffer_distance, cap_style="flat")
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
BufferedRails
# Out:
# 22951     POLYGON ((-84.69913 33.78855, -84.69913 33.788...
# 22952     POLYGON ((-84.75406 33.74920, -84.75202 33.750...
# 22953     POLYGON ((-84.69913 33.78855, -84.69913 33.788...
# 22954     POLYGON ((-84.90656 33.73065, -84.90656 33.730...
# 22955     POLYGON ((-84.75406 33.74920, -84.75202 33.750...
#                                 ...
# 117302    POLYGON ((-85.04996 33.74953, -85.04996 33.749...
# 117303    POLYGON ((-84.91157 33.73052, -84.91172 33.730...
# 117313    POLYGON ((-85.14559 33.72121, -85.14559 33.721...
# 117314    POLYGON ((-85.13736 33.69998, -85.13700 33.699...
# 117564    POLYGON ((-84.48057 33.80565, -84.48057 33.805...
# Length: 192, dtype: geometry

# %%
BufferedRails.head(1).plot(alpha =1, color='black')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(15, 15))
# BoundingBox.plot(ax=ax, alpha=0.5, color="pink")
# JoinRails.plot(ax=ax, color = 'red')
BufferedRails.plot(ax=ax, alpha =1, color='black')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(15, 15))
geo_df_NB_2018.plot(ax=ax, alpha=0.7, color="pink")
nyc_boroughBoundaries.plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,10))
NationShape.plot(ax=ax)
Overlay.plot(ax=ax, color = 'pink')
# Out:
# <Axes: >

# %%
gpd.overlay(bounding_box

# %% [markdown]
# # appendix

# %%
fn_area_water = '/Volumes/Extreme SSD/largest_plots/raw_data/area_water/tl_2023_01001_areawater.zip'
AreaWater = gpd.read_file(fn_area_water)

# %%
AreaWater
# Out:
#     ANSICODE       HYDROID        FULLNAME  MTFCC  ALAND   AWATER  \
# 0       None  110585123246            None  H2030      0     1058
# 1       None  110585122713     Motley Pond  H2030      0    19810
# 2       None  110585122709       Swift Crk  H2030      0  1185120
# 3       None  110585122725     Alabama Riv  H3010      0  1361299
# 4       None  110585122766  White Water Lk  H2030      0   232895
# ..       ...           ...             ...    ...    ...      ...
# 604     None  110585122928            None  H2030      0     4264
# 605     None  110585123087            None  H2030      0     3518
# 606     None  110585123097            None  H2030      0     1111
# 607     None  110585123101            None  H2030      0     3655
# 608     None  110585123109            None  H2030      0    17545
#
#         INTPTLAT     INTPTLON  \
# 0    +32.4475829  -86.7287169
# 1    +32.4854734  -86.6282779
# 2    +32.4107383  -86.6320375
# 3    +32.3952613  -86.8385000
# 4    +32.4690021  -86.6388877
# ..           ...          ...
# 604  +32.4168944  -86.4707801
# 605  +32.4471441  -86.4902889
# 606  +32.4323645  -86.4228744
# 607  +32.4211203  -86.4218673
# 608  +32.4040892  -86.4405392
#
#                                               geometry
# 0    POLYGON ((-86.72889 32.44744, -86.72886 32.447...
# 1    POLYGON ((-86.62903 32.48538, -86.62890 32.485...
# 2    POLYGON ((-86.64343 32.43036, -86.64342 32.430...
# 3    POLYGON ((-86.85780 32.43968, -86.85768 32.439...
# 4    POLYGON ((-86.64170 32.46588, -86.64136 32.466...
# ..                                                 ...
# 604  POLYGON ((-86.47120 32.41708, -86.47119 32.417...
# 605  POLYGON ((-86.49070 32.44708, -86.49066 32.447...
# 606  POLYGON ((-86.42312 32.43241, -86.42304 32.432...
# 607  POLYGON ((-86.42228 32.42120, -86.42224 32.421...
# 608  POLYGON ((-86.44237 32.40432, -86.44234 32.404...
#
# [609 rows x 9 columns]

# %%
yy = np.arange(start=24, stop=50, step=8.993999191439993e-06)
xx = np.arange(start=-125, stop=-66, step=2)
# xx = np.arange(start=-125, stop=-66, step=9.291531215312152e-06)

# %% [markdown]
# Scikit

# %%
y = 34.044727

y_dummy = np.repeat(y, len(xx))
Dummy = pd.DataFrame({
    'y':y,
    'x':xx
})
# grid_points
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 8
#       3 y_dummy = np.repeat(y, len(xx))
#       4 Dummy = pd.DataFrame({
#       5     'y':y,
#       6     'x':xx
#       7 })
# ----> 8 Point(Dummy.x, Dummy.y)
#
# File /opt/miniconda3/lib/python3.12/site-packages/shapely/geometry/point.py:73, in Point.__new__(self, *args)
#      70     coords = np.array(args).squeeze()
#      72 if coords.ndim > 1:
# ---> 73     raise ValueError(
#      74         f"Point() takes only scalar or 1-size vector arguments, got {args}"
#      75     )
#      76 if not np.issubdtype(coords.dtype, np.number):
#      77     coords = [float(c) for c in coords]
#
# ValueError: Point() takes only scalar or 1-size vector arguments, got (0    -125
# 1    -123
# 2    -121
# 3    -119
# 4    -117
# 5    -115
# 6    -113
# 7    -111
# 8    -109
# 9    -107
# 10   -105
# 11   -103
# 12   -101
# 13    -99
# 14    -97
# 15    -95
# 16    -93
# 17    -91
# 18    -89
# 19    -87
# 20    -85
# 21    -83
# 22    -81
# 23    -79
# 24    -77
# 25    -75
# 26    -73
# 27    -71
# 28    -69
# 29    -67
# Name: x, dtype: int64, 0     34.044727
# 1     34.044727
# 2     34.044727
# 3     34.044727
# 4     34.044727
# 5     34.044727
# 6     34.044727
# 7     34.044727
# 8     34.044727
# 9     34.044727
# 10    34.044727
# 11    34.044727
# 12    34.044727
# 13    34.044727
# 14    34.044727
# 15    34.044727
# 16    34.044727
# 17    34.044727
# 18    34.044727
# 19    34.044727
# 20    34.044727
# 21    34.044727
# 22    34.044727
# 23    34.044727
# 24    34.044727
# 25    34.044727
# 26    34.044727
# 27    34.044727
# 28    34.044727
# 29    34.044727
# Name: y, dtype: float64)

# %%
y = 34.044727
# y = 0
point_series = gpd.GeoSeries([Point(x, y) for x in xx])
point_series.crs = 'epsg:4269'
Points = gpd.GeoDataFrame(geometry=point_series)

# %%
# mask means 'does the national boundary contain this point'
Join = gdf.sjoin(Points, how="right", predicate='contains')
# does_national_boundary_contain_these_points = ~Join.index_left.isna()

# %%
Results = pd.DataFrame()
Results['x'] = list(compress(xx, does_national_boundary_contain_these_points))
Results['y'] = y
Results
# Out:
# Empty DataFrame
# Columns: [x, y]
# Index: []

# %%
list(compress(xx, does_national_boundary_contain_these_points))
# Out:
# [-117,
#  -115,
#  -113,
#  -111,
#  -109,
#  -107,
#  -105,
#  -103,
#  -101,
#  -99,
#  -97,
#  -95,
#  -93,
#  -91,
#  -89,
#  -87,
#  -85,
#  -83,
#  -81,
#  -79]

# %%
Points
# Out:
# 0     POINT (-125.00000 34.04473)
# 1     POINT (-123.00000 34.04473)
# 2     POINT (-121.00000 34.04473)
# 3     POINT (-119.00000 34.04473)
# 4     POINT (-117.00000 34.04473)
# 5     POINT (-115.00000 34.04473)
# 6     POINT (-113.00000 34.04473)
# 7     POINT (-111.00000 34.04473)
# 8     POINT (-109.00000 34.04473)
# 9     POINT (-107.00000 34.04473)
# 10    POINT (-105.00000 34.04473)
# 11    POINT (-103.00000 34.04473)
# 12    POINT (-101.00000 34.04473)
# 13     POINT (-99.00000 34.04473)
# 14     POINT (-97.00000 34.04473)
# 15     POINT (-95.00000 34.04473)
# 16     POINT (-93.00000 34.04473)
# 17     POINT (-91.00000 34.04473)
# 18     POINT (-89.00000 34.04473)
# 19     POINT (-87.00000 34.04473)
# 20     POINT (-85.00000 34.04473)
# 21     POINT (-83.00000 34.04473)
# 22     POINT (-81.00000 34.04473)
# 23     POINT (-79.00000 34.04473)
# 24     POINT (-77.00000 34.04473)
# 25     POINT (-75.00000 34.04473)
# 26     POINT (-73.00000 34.04473)
# 27     POINT (-71.00000 34.04473)
# 28     POINT (-69.00000 34.04473)
# 29     POINT (-67.00000 34.04473)
# dtype: geometry

# %%
gdf.sjoin(Points)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 gdf.sjoin(Points)
#
# File /opt/miniconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:2195, in GeoDataFrame.sjoin(self, df, *args, **kwargs)
#    2121 def sjoin(self, df, *args, **kwargs):
#    2122     """Spatial join of two GeoDataFrames.
#    2123
#    2124     See the User Guide page :doc:`../../user_guide/mergingdata` for details.
#    (...)
#    2193     sjoin : equivalent top-level function
#    2194     """
# -> 2195     return geopandas.sjoin(left_df=self, right_df=df, *args, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/geopandas/tools/sjoin.py:119, in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     116     first = next(iter(kwargs.keys()))
#     117     raise TypeError(f"sjoin() got an unexpected keyword argument '{first}'")
# --> 119 _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     121 indices = _geom_predicate_query(left_df, right_df, predicate)
#     123 joined = _frame_join(indices, left_df, right_df, how, lsuffix, rsuffix)
#
# File /opt/miniconda3/lib/python3.12/site-packages/geopandas/tools/sjoin.py:152, in _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     147     raise ValueError(
#     148         "'left_df' should be GeoDataFrame, got {}".format(type(left_df))
#     149     )
#     151 if not isinstance(right_df, GeoDataFrame):
# --> 152     raise ValueError(
#     153         "'right_df' should be GeoDataFrame, got {}".format(type(right_df))
#     154     )
#     156 allowed_hows = ["left", "right", "inner"]
#     157 if how not in allowed_hows:
#
# ValueError: 'right_df' should be GeoDataFrame, got <class 'geopandas.geoseries.GeoSeries'>

# %%
gdf.contains(pt0)
# Out:
# 0    False
# dtype: bool
