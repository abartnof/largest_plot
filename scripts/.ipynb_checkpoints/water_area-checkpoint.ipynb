# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
# from shapely.geometry import Point, box, LineString
from shapely import intersection
from tqdm.notebook import tqdm
import glob

target_epsg = 6350  # https://epsg.org/crs_6350/NAD83-2011-Conus-Albers.html?sessionkey=nb47agmo4r

# %%
fn_aoi = '/Volumes/Extreme SSD/largest_plots/clean_data/aoi.parquet'
fn_water_area_overlay = '/Volumes/Extreme SSD/largest_plots/clean_data/water_area_overlay.parquet'
dir_water_area = '/Volumes/Extreme SSD/largest_plots/raw_data/area_water/*.zip'

# %%
Aoi = gpd.read_parquet(fn_aoi).set_geometry('aoi').set_crs(epsg=target_epsg)

# %%
pattern_water_area = dir_water_area + '/*.zip'
fn_list_water_area = glob.glob(dir_water_area)

# %% [markdown]
# Iterate through each AOI x each water area file.
# - Keep any rows that overlap at all with the AOI
# - Each AOI's results will be stored as a list of geopandas tables.

# %%
intersection_dict = {}
for i in Aoi.index:
    intersection_dict[i] = list()

for fn_water_area in tqdm(fn_list_water_area):
    WaterArea = gpd.read_file(fn_water_area).to_crs(epsg=target_epsg)
    
    for i in Aoi.index:
        single_aoi = Aoi.loc[[i]]
        Intersection = gpd.sjoin(WaterArea, single_aoi, how='inner', predicate='intersects')
        if Intersection.shape[0] > 0:
            intersection_dict[i].append(Intersection)
        else:
            pass
# Out:
#   0%|          | 0/3235 [00:00<?, ?it/s]

# %% [markdown]
# For each entry in the previous dictionary:
# - flatten the list of tables into one table
# - flatten the geometries in this new table into one geometry file
# - trim the flat geometry to the dimensions of the AOI box

# %%
# Did each AOI have an intersection?
len(intersection_dict.keys()) == len(Aoi)
# Out:
# True

# %% [markdown]
# Iterate through the above dictionary, actually calculating the intersection between each AOI and the relevant water area polygons

# %%
overlay_dict = {}

for i in tqdm(intersection_dict.keys()):  # iterate through these indices, because in theory, an index from the AOI might not have intersected at all with the water files
    intersections_in_list = intersection_dict[i]
    water_area_flat = pd.concat(intersections_in_list).reset_index(drop=True).unary_union

    single_aoi = Aoi.loc[[i]]
    overlay = single_aoi.intersection(water_area_flat).to_frame().reset_index(drop=True).loc[0,0]
    overlay_dict[i] = overlay
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
intersection_dict.keys() == overlay_dict.keys()
# Out:
# True

# %%
WaterAreaOverlay = gpd.GeoDataFrame({'index':overlay_dict.keys(), 'geometry':overlay_dict.values()}, crs='epsg:'+str(target_epsg))
WaterAreaOverlay.set_geometry('geometry', inplace=True)
WaterAreaOverlay.set_index('index', drop=True, inplace=True, verify_integrity=True)
WaterAreaOverlay.head()
# Out:
#                                                 geometry
# index
# 0      MULTIPOLYGON (((1064783.733 1236553.809, 10647...
# 1      MULTIPOLYGON (((1253970.757 1239888.748, 12539...
# 2      MULTIPOLYGON (((1280030.297 1419846.933, 12799...
# 3      MULTIPOLYGON (((1652992.164 1562473.896, 16529...
# 4      MULTIPOLYGON (((1517647.954 1481718.806, 15176...

# %% [markdown]
# # Manual QC fun:

# %%
# Note that these are 'buffered', ie expanded, so we can see them easily here.
i = 1
fig, ax = plt.subplots(figsize=(5, 5))
Aoi.loc[[i]].boundary.plot(ax=ax)
gpd.GeoDataFrame(pd.concat(intersection_dict[i])).buffer(distance=1000).plot(ax=ax, color='black')
WaterAreaOverlay.loc[[i]].buffer(distance=500).plot(ax=ax, color='red')
# Out:
# <Axes: >

# %% [markdown]
# # Save to disk

# %%
WaterAreaOverlay.to_parquet(fn_water_area_overlay)
